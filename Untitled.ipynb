# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
data = pd.read_csv("HW4_Train_Data.csv")

# %%
print(data)
# Out:
#       UNIX Timestamp (seconds) Start Time (GMT-0800,PST)  \
# 0                   1388851200              1/5/14 00:00
# 1                   1388854800              1/5/14 01:00
# 2                   1388858400              1/5/14 02:00
# 3                   1388862000              1/5/14 03:00
# 4                   1388865600              1/5/14 04:00
# ...                        ...                       ...
# 8563                1419678000            12/27/14 19:00
# 8564                1419681600            12/27/14 20:00
# 8565                1419685200            12/27/14 21:00
# 8566                1419688800            12/27/14 22:00
# 8567                1419692400            12/27/14 23:00
#
#      End Time (GMT-0800,PST)  Bldg1 (kWh)  Bldg2 (kWh)  Bldg3 (kWh)  \
# 0               1/5/14 00:59         0.19         0.97         0.03
# 1               1/5/14 01:59         0.19         0.83         0.10
# 2               1/5/14 02:59         0.19         0.89         0.08
# 3               1/5/14 03:59         0.19         0.83         0.03
# 4               1/5/14 04:59         0.19         0.83         0.03
# ...                      ...          ...          ...          ...
# 8563          12/27/14 19:59         0.31         1.27         0.07
# 8564          12/27/14 20:59         0.25         1.30         0.08
# 8565          12/27/14 21:59         0.14         1.12         0.04
# 8566          12/27/14 22:59         0.14         1.09         0.08
# 8567          12/27/14 23:59         0.11         3.82         0.04
#
#       Bldg4 (kWh)  Bldg5 (kWh)  Bldg6 (kWh)  Bldg7 (kWh)  ...  Bldg14 (kWh)  \
# 0            0.02         0.26         1.47         0.10  ...          0.24
# 1            0.02         0.26         1.48         0.20  ...          0.40
# 2            0.08         0.24         1.45         0.10  ...          0.36
# 3            0.02         0.17         1.45         0.18  ...          0.33
# 4            0.02         0.18         1.69         0.14  ...          0.29
# ...           ...          ...          ...          ...  ...           ...
# 8563         0.02         0.06         3.10         0.53  ...          0.08
# 8564         0.06         0.26         3.36         3.08  ...          0.07
# 8565         0.02         0.30         1.89         2.20  ...          0.09
# 8566         0.02         0.29         1.44         0.92  ...          0.06
# 8567         0.04         0.14         1.36         0.30  ...          0.09
#
#       Bldg15 (kWh)  Bldg16 (kWh)  Bldg17 (kWh)  Bldg18 (kWh)  Bldg19 (kWh)  \
# 0             1.76          0.11          0.09          0.61          0.03
# 1             1.49          0.06          0.10          0.77          0.03
# 2             1.57          0.05          0.08          0.75          0.03
# 3             1.31          0.06          0.13          0.34          0.02
# 4             0.03          0.06          0.16          0.15          0.03
# ...            ...           ...           ...           ...           ...
# 8563          0.05          0.05          0.08          0.37          0.02
# 8564          0.00          0.05          0.06          1.18          0.02
# 8565          0.00          0.05          0.07          0.62          0.02
# 8566          0.05          0.01          0.07          0.36          0.03
# 8567          0.00          0.05          0.06          0.38          0.02
#
#       Bldg20 (kWh)  Bldg21 (kWh)  Bldg22 (kWh)  Bldg23 (kWh)
# 0             1.70          3.23          0.14          0.99
# 1             1.78          2.42          0.12          0.93
# 2             1.68          2.31          0.13          0.47
# 3             1.70          2.72          0.14          0.58
# 4             1.75          0.69          0.11          0.44
# ...            ...           ...           ...           ...
# 8563          2.32          1.25          0.09          0.15
# 8564          2.09          1.24          0.10          0.17
# 8565          1.64          1.22          0.10          0.15
# 8566          1.29          1.22          0.10          0.16
# 8567          1.02          1.22          0.10          0.15
#
# [8568 rows x 26 columns]

# %%
print(data["Bldg1 (kWh)"])
# Out:
# 0       0.19
# 1       0.19
# 2       0.19
# 3       0.19
# 4       0.19
#         ...
# 8563    0.31
# 8564    0.25
# 8565    0.14
# 8566    0.14
# 8567    0.11
# Name: Bldg1 (kWh), Length: 8568, dtype: float64

# %%
build_avg_consumption = []
build_std_consumption = []
for i in range(19):
    temp = np.mean(data["Bldg%d (kWh)"%(i+1)])
    build_avg_consumption.append(temp)
    build_std_consumption.append(np.std(data["Bldg%d (kWh)"%(i+1)]))
print(build_avg_consumption)
# Out:
# [0.13230859010270776, 1.4321218487394956, 0.18762021475256768, 0.24053221288515408, 0.12135971055088704, 0.6064098972922503, 0.4526353874883287, 0.2863048552754436, 0.22728408029878622, 0.2525711951447246, 0.165765639589169, 0.3864110644257703, 0.21447829131652663, 0.17772175536881418, 0.14771825396825397, 0.2172514005602241, 0.18385737628384688, 0.29989028944911306, 0.15576797385620914]

# %%
building_index = [i+1 for i in range(19)]
fig, ax = plt.subplots()
ax.bar(building_index, build_avg_consumption)
ax.errorbar(building_index, build_avg_consumption, yerr=build_std_consumption, fmt='o', color='red')
ax.set_xlabel('Building index')
ax.set_ylabel('Average Consumption')
# Out:
# Text(0, 0.5, 'Average Consumption')

# %%
for i in range(19):
    for j in range(len(data["Bldg%d (kWh)"%(i+1)])):
        if data["Bldg%d (kWh)"%(i+1)][j] < 0:
            print("building %d has negative values"%(i+1))
            break
# Out:
# building 6 has negative values

# %% [markdown]
# Building 6 has abnormal high variance and has nagatve power consumption

# %% [markdown]
# After removing the building 6

# %%
build_avg_consumption = []
build_std_consumption = []
for i in range(19):
    if i != 5:
        temp = np.mean(data["Bldg%d (kWh)"%(i+1)])
        build_avg_consumption.append(temp)
        build_std_consumption.append(np.std(data["Bldg%d (kWh)"%(i+1)]))
building_index = [i+1 for i in range(18)]
fig, ax = plt.subplots()
ax.bar(building_index, build_avg_consumption)
ax.errorbar(building_index, build_avg_consumption, yerr=build_std_consumption, fmt='o', color='red')
ax.set_xlabel('Building index')
ax.set_ylabel('Average Consumption')
# Out:
# Text(0, 0.5, 'Average Consumption')

# %%
build_avg_consumption = []
build_std_consumption = []
build_max_consumption = []
for i in range(19):
    if i != 5:
        temp = np.mean(data["Bldg%d (kWh)"%(i+1)])
        build_avg_consumption.append(temp)
        build_std_consumption.append(np.std(data["Bldg%d (kWh)"%(i+1)]))
        build_max_consumption.append(np.max(data["Bldg%d (kWh)"%(i+1)]))

# %%
date_obj = datetime.datetime.strptime(date_string, '%m/%d/%y %H:%M')

# %%
print(data.loc[0])
print(    data.loc[0]["Start Time (GMT-0800,PST)"])
# Out:
# UNIX Timestamp (seconds)       1388851200
# Start Time (GMT-0800,PST)    1/5/14 00:00
# End Time (GMT-0800,PST)      1/5/14 00:59
# Bldg1 (kWh)                          0.19
# Bldg2 (kWh)                          0.97
# Bldg3 (kWh)                          0.03
# Bldg4 (kWh)                          0.02
# Bldg5 (kWh)                          0.26
# Bldg6 (kWh)                          1.47
# Bldg7 (kWh)                           0.1
# Bldg8 (kWh)                           0.1
# Bldg9 (kWh)                          0.34
# Bldg10 (kWh)                         0.07
# Bldg11 (kWh)                         0.04
# Bldg12 (kWh)                          0.2
# Bldg13 (kWh)                         0.05
# Bldg14 (kWh)                         0.24
# Bldg15 (kWh)                         1.76
# Bldg16 (kWh)                         0.11
# Bldg17 (kWh)                         0.09
# Bldg18 (kWh)                         0.61
# Bldg19 (kWh)                         0.03
# Bldg20 (kWh)                          1.7
# Bldg21 (kWh)                         3.23
# Bldg22 (kWh)                         0.14
# Bldg23 (kWh)                         0.99
# Name: 0, dtype: object
# 1/5/14 00:00

# %%
size = len(data) * 18
random_data = np.random.rand(size, 5)

# Create a pandas DataFrame from the numpy array
organized_data = pd.DataFrame(random_data, columns=['Building_index', 'week_of_year', 'day_of_week', 'hour_of_day',"normalized_energy"])
index = 0

build_max_consumption = []
for i in range(19):
    if i == 5:
        build_max_consumption.append(None)
    if i != 5:
        build_max_consumption.append(np.max(data["Bldg%d (kWh)"%(i+1)]))

for i in range(len(data)):
    temp = data.loc[i]
    date_string = temp["Start Time (GMT-0800,PST)"]
    date_obj = datetime.datetime.strptime(date_string, '%m/%d/%y %H:%M')
    week_of_year = date_obj.isocalendar()[1]
    day_of_week = date_obj.weekday()
    hour_of_day = date_obj.hour
    for j in range(19):
        if j != 5:
            value = temp["Bldg%d (kWh)"%(j+1)] / build_max_consumption[j]
            organized_data.loc[index] = [(j+1), week_of_year, day_of_week,hour_of_day, value ]
            index += 1
print(organized_data)
# Out:
#         Building_index  week_of_year  day_of_week  hour_of_day  \
# 0                  1.0           1.0          6.0          0.0
# 1                  2.0           1.0          6.0          0.0
# 2                  3.0           1.0          6.0          0.0
# 3                  4.0           1.0          6.0          0.0
# 4                  5.0           1.0          6.0          0.0
# ...                ...           ...          ...          ...
# 154219            15.0          52.0          5.0         23.0
# 154220            16.0          52.0          5.0         23.0
# 154221            17.0          52.0          5.0         23.0
# 154222            18.0          52.0          5.0         23.0
# 154223            19.0          52.0          5.0         23.0
#
#         normalized_energy
# 0                0.234568
# 1                0.082343
# 2                0.021277
# 3                0.006536
# 4                0.393939
# ...                   ...
# 154219           0.000000
# 154220           0.017241
# 154221           0.038710
# 154222           0.220930
# 154223           0.006349
#
# [154224 rows x 5 columns]

# %%
grouped = organized_data.groupby(["week_of_year",'day_of_week',"Building_index",'hour_of_day'])['normalized_energy'].mean()

# %%
for name in grouped:
    print(name)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 0.009036144578313253
# 0.006024096385542169
# 0.0
# 0.0
# 0.015060240963855423
# 0.0
# 0
# Name: normalized_energy, Length: 154224, dtype: float64

# %%
print(grouped[1])
print(len(grouped[1][6]))
# print(len(grouped[0][1]))
# Out:
# day_of_week  Building_index  hour_of_day
# 6.0          1.0             0.0            0.234568
#                              1.0            0.234568
#                              2.0            0.234568
#                              3.0            0.234568
#                              4.0            0.234568
#                                               ...
#              19.0            19.0           0.012698
#                              20.0           0.012698
#                              21.0           0.012698
#                              22.0           0.034921
#                              23.0           0.015873
# Name: normalized_energy, Length: 432, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 2
#       1 print(grouped[1])
# ----> 2 print(len(grouped[1][1]))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2916, in MultiIndex.get_loc(self, key, method)
#    2913     return mask
#    2915 if not isinstance(key, tuple):
# -> 2916     loc = self._get_level_indexer(key, level=0)
#    2917     return _maybe_to_slice(loc)
#    2919 keylen = len(key)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3290, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3286     end = algos.searchsorted(level_codes, idx, side="right")
#    3288 if start == end:
#    3289     # The label is present in self.levels[level] but unused:
# -> 3290     raise KeyError(key)
#    3291 return slice(start, end)
#
# KeyError: 1

# %%
print(grouped[2])
# Out:
# day_of_week  Building_index  hour_of_day
# 0.0          1.0             0.0            0.246914
#                              1.0            0.246914
#                              2.0            0.246914
#                              3.0            0.246914
#                              4.0            0.246914
#                                               ...
# 6.0          19.0            19.0           0.047619
#                              20.0           0.050794
#                              21.0           0.025397
#                              22.0           0.019048
#                              23.0           0.012698
# Name: normalized_energy, Length: 3024, dtype: float64

# %%
grouped_by_hour = organized_data.groupby(["day_of_week",'hour_of_day'])['normalized_energy'].mean()
print(grouped_by_hour[0])
# Out:
# hour_of_day
# 0.0     0.114915
# 1.0     0.094641
# 2.0     0.081565
# 3.0     0.071879
# 4.0     0.073287
# 5.0     0.076234
# 6.0     0.109249
# 7.0     0.108510
# 8.0     0.107752
# 9.0     0.100563
# 10.0    0.107012
# 11.0    0.095344
# 12.0    0.098863
# 13.0    0.095688
# 14.0    0.084756
# 15.0    0.087543
# 16.0    0.100951
# 17.0    0.112716
# 18.0    0.136080
# 19.0    0.146971
# 20.0    0.168214
# 21.0    0.185803
# 22.0    0.163899
# 23.0    0.145100
# Name: normalized_energy, dtype: float64

# %%
day_hash_map = {0: "Sunday",
                1: "Monday",
                2: "Tuesday",
                3: "Wednesday",
                4: "Thursday",
                5: "Friday",
                6: "Saturday"}
for i in range(7):
    plt.figure()
    for week in range(1,53):
        for j in range(1,19):
            if j != 6:
                consumption = []
                try:
                    temp = grouped[week][i][j]
                    hours = [i for i in range(24)]
                    for h in hours:
                        consumption.append(temp[h])
                    plt.plot(hours, consumption)
#                     plt.title(day_hash_map[i])
#                     plt.xlabel("Time of the day")
#                     plt.ylabel("Normalized Hourly Energy")
                except:
                    pass
    consumption = []  
    avg_group = grouped_by_hour[i]
    hours = [i for i in range(24)]
    for h in hours:
        consumption.append(avg_group[h])
    plt.plot(hours, consumption,linewidth=3, color='black')
    plt.title(day_hash_map[i])
    plt.xlabel("Time of the day")
    plt.ylabel("Normalized Hourly Energy")
#   print(grouped[i])
